# %%
#Phương trình hàm bậc 2. y = ax^2 + bx + c
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 2
b = -2
m = 100

X = np.random.randn(m) * 10
Y = a*X**2 + b*X + np.random.randn(m) * 100

#Y = Y / np.max(Y)

plt.plot(X,Y,'ro')

# %%
def Y_Hat(a,b,c,x):
    return a*x**2 + b*x + c

def cost(x,y,a,b,c):
    y_hat = Y_Hat(a, b, c, x)
    return np.sum((y_hat - y)**2)/(2*m)

a = 3
b = 4
c = 5
learning_rate = 0.00002

cost_arr = []

for i in np.arange(2000000):
    y_hat = Y_Hat(a, b, c, X)
    a = a - learning_rate*(np.sum((y_hat - Y)*X**2))/m                     
    b = b - learning_rate*(np.sum((y_hat - Y)*X))/m
    c = c - learning_rate*(np.sum((y_hat - Y)))/m
    cost_arr.append(cost(X,Y,a,b,c))

# %%
plt.plot(cost_arr)

# %%
print (a,b,c)
# Out:
# 2.0156263901690226 -2.8448020316262057 -22.778322895414817

# %%
x0 = np.linspace(-30,30,20)
y0 = Y_Hat(a,b,c, x0)
plt.plot(x0,y0)

plt.plot(X, Y, 'ro')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
XX = X.reshape(m, 1)
poly = PolynomialFeatures(degree=2)
XX = poly.fit_transform(XX)
model = LinearRegression()
model.fit(XX, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
temp = model.predict(XX)

# %%
c, b, a = model.coef_

# %%
x0 = np.linspace(-30, 30, 20)
y0 = Y_Hat(a,b,c, x0)

plt.plot(x0,y0)
plt.plot(X,Y, 'ro')

# %%
print(a, b, c)
# Out:
# 2.015626390169479 -2.844802031626356 0.0
