# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
plt.rcParams['font.family'] = 'Sans-serif' #全体のフォントを設定
plt.rcParams["figure.figsize"] = [20, 7]
plt.rcParams['font.size'] = 12 #フォントサイズを設定 default : 12
plt.rcParams['xtick.labelsize'] = 15 # 横軸のフォントサイズ
plt.rcParams['ytick.labelsize'] = 15

# %% [markdown]
# ### 1. Possion Distribution
#
# Trong lý thuyết xác suất và thống kê, Phân phối Poisson (phân phối Poa-xông) là một phân phối xác suất rời rạc. Nó khác với các phân phối xác suất rời rạc khác ở chỗ thông tin cho biết không phải là xác suất để một sự kiện (event) xảy ra (thành công) trong một lần thử như trong phân phối Bernoulli, hay là số lần mà sự kiện đó xảy ra trong n lần thử như trong phân phối nhị thức, mà chính là trung bình số lần xảy ra thành công của một sự kiện trong một khoảng thời gian nhất định.
#
# ###### Giá trị trung bình này được gọi là lamda, ký hiệu là
# \begin{align}
# {\displaystyle \lambda }
# \end{align}
#
#
# Phân phối Poisson còn được dùng cho khoảng mà đơn vị khác thời gian như: khoảng cách, diện tích hay thể tích. Một ví dụ cổ điển là sự phân rã hạt nhân của các nguyên tử.
#
# Phân phối này được tìm ra bởi nhà toán học Siméon-Denis Poisson (1781–1840) và đã được xuất bản cùng với lý thuyết xác suất của ông, vào năm 1838 với tựa đề Recherches sur la probabilité des jugements en matières criminelles et matière civile ("Research on the Probability of Judgments in Criminal and Civil Matters"). Theo đó, nếu xem xét một biến ngẫu nhiên N nào đó, và đếm số lần xuất hiện (rời rạc) của nó trong một khoảng thời gian cho trước. Nếu giá trị kì vọng (hay số lần trung bình mà biến ngẫu nhiên đó xảy ra trong khoảng thời gian đó là λ, thì xác suất để cũng chính sự kiện đó xảy ra k lần (k là số nguyên không âm, k = 0, 1, 2,...) sẽ được tính theo công thức
#
#
# https://vi.wikipedia.org/wiki/Ph%C3%A2n_ph%E1%BB%91i_Poisson

# %%
N = 1000
LAMBDA = 30
START_DATE = '1/1/2005'

sale_value = np.random.poisson(LAMBDA, N)
sale_datetime = pd.date_range(start=START_DATE, periods= N)

# %% [markdown]
# ### 1. Data Prepare
#
# Tổng doanh thu mỗi ngày tại 1 cửa hàng, có phân phối Poisson

# %%
SaleData = pd.DataFrame(np.transpose([sale_value, sale_datetime]), columns=['Sale_value', 'Sale_date'])
SaleData[0:10]
# Out:
#   Sale_value            Sale_date
# 0         38  2005-01-01 00:00:00
# 1         23  2005-01-02 00:00:00
# 2         42  2005-01-03 00:00:00
# 3         22  2005-01-04 00:00:00
# 4         25  2005-01-05 00:00:00
# 5         22  2005-01-06 00:00:00
# 6         30  2005-01-07 00:00:00
# 7         27  2005-01-08 00:00:00
# 8         35  2005-01-09 00:00:00
# 9         22  2005-01-10 00:00:00

# %% [markdown]
# ### 1.1 Doanh thu trung bình mỗi tháng

# %%
SaleData['Month'] = [x.month for x in SaleData.Sale_date]
SaleData['Year'] = [x.year for x in SaleData.Sale_date]

SaleData['Sale_value'] = pd.to_numeric(SaleData['Sale_value'])

SaleData.groupby(['Year', 'Month'], as_index=False)['Sale_value'].mean()
# Out:
#     Year  Month  Sale_value
# 0   2005      1   30.096774
# 1   2005      2   29.892857
# 2   2005      3   33.064516
# 3   2005      4   29.433333
# 4   2005      5   30.096774
# 5   2005      6   28.833333
# 6   2005      7   31.258065
# 7   2005      8   29.483871
# 8   2005      9   28.633333
# 9   2005     10   30.096774
# 10  2005     11   30.600000
# 11  2005     12   29.193548
# 12  2006      1   28.290323
# 13  2006      2   31.714286
# 14  2006      3   30.612903
# 15  2006      4   28.966667
# 16  2006      5   28.161290
# 17  2006      6   29.700000
# 18  2006      7   30.290323
# 19  2006      8   29.903226
# 20  2006      9   31.000000
# 21  2006     10   28.741935
# 22  2006     11   31.600000
# 23  2006     12   31.225806
# 24  2007      1   30.096774
# 25  2007      2   29.035714
# 26  2007      3   30.161290
# 27  2007      4   31.900000
# 28  2007      5   28.548387
# 29  2007      6   29.966667
# 30  2007      7   29.290323
# 31  2007      8   28.806452
# ...

# %% [markdown]
# ### 1.2 Số lần xuất hiện doanh thu theo từng ngày

# %%
pd.DataFrame(Sale_Month.groupby(['Sale_value_round'])['Sale_value'].count())
# Out:
#                   Sale_value
# Sale_value_round
# 14                         1
# 16                         2
# 17                         1
# 18                         5
# 19                         7
# 20                        14
# 21                        20
# 22                        34
# 23                        31
# 24                        44
# 25                        67
# 26                        49
# 27                        58
# 28                        70
# 29                        63
# 30                        88
# 31                        80
# 32                        62
# 33                        61
# 34                        45
# 35                        46
# 36                        34
# 37                        26
# 38                        24
# 39                        22
# 40                        15
# 41                        11
# 42                         7
# 43                         2
# 44                         7
# ...

# %% [markdown]
# ### 1.3 Sales of values in the Next day
#
# Tính xác suất doanh thu trong 1 ngày 2017/08 đạt 31 tỉ đồng

# %%
pd.DataFrame(Sale_Month.groupby(['Sale_value'])['Sale_value'].count()).plot.bar()

# %% [markdown]
# ##### Lambda

# %%
Lamda = Sale_Month.Sale_value.mean()

show_Data = pd.DataFrame(Sale_Month.groupby(['Sale_value'])['Sale_value'].count())
# Out:
# Index(['Sale_value'], dtype='object')

# %% [markdown]
# ### Số lần đạt doanh thu theo khoảng 1 ngày

# %%
fig, ax = plt.subplots()
plt.axvline(x = float(Lamda), linestyle = 'dashed',  linewidth=2, color = 'r')
plt.plot(show_Data)
plt.xlabel('Sales Values')
plt.ylabel('Sales Number')
# Out:
# Text(0,0.5,'Sales Number')

# %%
25/show_Data.Sale_value.sum()
# Out:
# 0.025

# %%
(np.exp(-30)* np.power(30, 25))/math.factorial(25)
# Out:
# 3.0364142066845233e-30

# %%
show_Data
# Out:
#             Sale_value
# Sale_value
# 14                   1
# 16                   2
# 17                   1
# 18                   5
# 19                   7
# 20                  14
# 21                  20
# 22                  34
# 23                  31
# 24                  44
# 25                  67
# 26                  49
# 27                  58
# 28                  70
# 29                  63
# 30                  88
# 31                  80
# 32                  62
# 33                  61
# 34                  45
# 35                  46
# 36                  34
# 37                  26
# 38                  24
# 39                  22
# 40                  15
# 41                  11
# 42                   7
# 43                   2
# 44                   7
# 45                   1
# 46                   2
# 50                   1
